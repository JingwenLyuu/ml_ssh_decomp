# %% [markdown]
# # Set up

# %%
import random
import numpy as np
import xarray as xr
import torch
from torch.utils.data import DataLoader, TensorDataset
from unet import *
from train import *
from loss import *

base_path = "gs://leap-persistent/YueWang/SSH/data"

def open_zarr(path):
    return xr.open_zarr(path, consolidated=True)

train = open_zarr(f"{base_path}/train_108_sst.zarr").compute()
val = open_zarr(f"{base_path}/val_108_sst.zarr").compute()
zca = open_zarr(f"{base_path}/zca_108_sst.zarr").compute()

# %%
def min_max_normalize(tensor, min_values=None, max_values=None, feature_range=(0, 1)):

    num_channels = tensor.shape[1]
    
    if min_values is None:
        min_values = torch.zeros(num_channels, device=tensor.device)
        for c in range(num_channels):
            min_values[c] = tensor[:, c, :, :].min()
    
    if max_values is None:
        max_values = torch.zeros(num_channels, device=tensor.device)
        for c in range(num_channels):
            max_values[c] = tensor[:, c, :, :].max()
    
    normalized_tensor = torch.zeros_like(tensor)
    scale = (feature_range[1] - feature_range[0])
    
    # Normalize each channel independently
    for c in range(num_channels):
        channel_range = max_values[c] - min_values[c]
        
        # Handle edge case where min and max are the same
        if channel_range == 0:
            normalized_tensor[:, c, :, :] = feature_range[0]
        else:
            # Apply min-max formula: (x - min) / (max - min) * scale + min_range
            normalized_tensor[:, c, :, :] = (
                (tensor[:, c, :, :] - min_values[c]) / channel_range
            ) * scale + feature_range[0]
    
    return normalized_tensor, min_values, max_values

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Prepare training data
x_train_channel_0 = torch.from_numpy(train.ssh.values).float().unsqueeze(1).to(device)
x_train_channel_1 = torch.from_numpy(train.sst.values).float().unsqueeze(1).to(device)
x_train = torch.cat([x_train_channel_0, x_train_channel_1], dim=1)
x_train_normalized, min_values, max_values = min_max_normalize(x_train)

y_train_channel_0 = torch.from_numpy(train.ubm.values).float().unsqueeze(1).to(device)
y_train_channel_1 = torch.from_numpy(train.zca_ubm.values).float().unsqueeze(1).to(device)
y_train = torch.cat([y_train_channel_0, y_train_channel_1], dim=1)


# Prepare validation data 
x_val_channel_0 = torch.from_numpy(val.ssh.values).float().unsqueeze(1).to(device)
x_val_channel_1 = torch.from_numpy(val.sst.values).float().unsqueeze(1).to(device)
x_val = torch.cat([x_val_channel_0, x_val_channel_1], dim=1)
x_val_normalized, _, _ = min_max_normalize(x_val, min_values=min_values, max_values=max_values)

y_val_channel_0 = torch.from_numpy(val.ubm.values).float().unsqueeze(1).to(device)
y_val_channel_1 = torch.from_numpy(val.zca_ubm.values).float().unsqueeze(1).to(device)  
y_val = torch.cat([y_val_channel_0, y_val_channel_1], dim=1)  

# Create datasets
train_dataset = TensorDataset(x_train_normalized, y_train)
val_dataset = TensorDataset(x_val_normalized, y_val)


# Create data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

Vt = torch.from_numpy(zca.zca_Vt_ubm.values).float().to(device)
scale = torch.from_numpy(zca.zca_scale_ubm.values).float().to(device)
mean = torch.from_numpy(zca.zca_mean_ubm.values).float().to(device)

# %% [markdown]
# # Training

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    

# Create model and optimizer
model = UNet(in_channels=2, out_channels=2, initial_features=32, depth=4)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)


train_model(model, train_loader, val_loader,
            Vt, scale, mean,  
            optimizer, device,
            grad_loss_weight=0.0,      # Weight for gradient loss in physical space
            mse_loss_weight=0.0,       # Weight for MSE loss in physical space  
            zca_nll_weight=1.0,        # Weight for ZCA Gaussian NLL loss
            save_path='/home/jovyan/GRL_ssh/checkpoints/ps108.pth',
            n_epochs=2000,
            patience=50)
# Out:
# Epoch 1, Train Loss: 4.33e-01 (ZCA-NLL: 4.33e-01, MSE-Phys: 1.13e-04, Grad-Phys: 2.39e-04), Val Loss: 5.50e+00, Epoch Time: 125.39s
# Best model so far saved at epoch 1 (Val Loss: 5.496e+00)
# Epoch 2, Train Loss: 2.59e-01 (ZCA-NLL: 2.59e-01, MSE-Phys: 1.36e-04, Grad-Phys: 1.97e-04), Val Loss: 5.03e+00, Epoch Time: 124.88s
# Best model so far saved at epoch 2 (Val Loss: 5.035e+00)
# Epoch 3, Train Loss: 9.55e-02 (ZCA-NLL: 9.55e-02, MSE-Phys: 1.11e-04, Grad-Phys: 1.52e-04), Val Loss: 4.69e+00, Epoch Time: 125.08s
# Best model so far saved at epoch 3 (Val Loss: 4.688e+00)
# Epoch 4, Train Loss: 6.26e-02 (ZCA-NLL: 6.26e-02, MSE-Phys: 9.06e-05, Grad-Phys: 1.40e-04), Val Loss: 4.55e+00, Epoch Time: 124.96s
# Best model so far saved at epoch 4 (Val Loss: 4.555e+00)
# Epoch 5, Train Loss: 4.90e-02 (ZCA-NLL: 4.90e-02, MSE-Phys: 8.61e-05, Grad-Phys: 1.34e-04), Val Loss: 4.60e+00, Epoch Time: 124.99s
# Patience counter: 1/50
# Epoch 6, Train Loss: 3.95e-02 (ZCA-NLL: 3.95e-02, MSE-Phys: 8.16e-05, Grad-Phys: 1.29e-04), Val Loss: 4.52e+00, Epoch Time: 124.78s
# Best model so far saved at epoch 6 (Val Loss: 4.516e+00)
# Epoch 7, Train Loss: 3.15e-02 (ZCA-NLL: 3.15e-02, MSE-Phys: 7.73e-05, Grad-Phys: 1.24e-04), Val Loss: 4.57e+00, Epoch Time: 125.04s
# Patience counter: 1/50
# Epoch 8, Train Loss: 2.63e-02 (ZCA-NLL: 2.63e-02, MSE-Phys: 7.84e-05, Grad-Phys: 1.24e-04), Val Loss: 4.52e+00, Epoch Time: 125.03s
# Patience counter: 2/50
# Epoch 9, Train Loss: 2.19e-02 (ZCA-NLL: 2.19e-02, MSE-Phys: 7.59e-05, Grad-Phys: 1.21e-04), Val Loss: 4.53e+00, Epoch Time: 124.96s
# Patience counter: 3/50
# Epoch 10, Train Loss: 1.72e-02 (ZCA-NLL: 1.72e-02, MSE-Phys: 7.06e-05, Grad-Phys: 1.16e-04), Val Loss: 4.50e+00, Epoch Time: 124.97s
# Best model so far saved at epoch 10 (Val Loss: 4.504e+00)
Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.39e+00, Epoch Time: 125.19s
# Patience counter: 5/50
# Epoch 80, Train Loss: -3.49e-02 (ZCA-NLL: -3.49e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.36e+00, Epoch Time: 125.22s
# Patience counter: 6/50
# Epoch 81, Train Loss: -3.49e-02 (ZCA-NLL: -3.49e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.72e-05), Val Loss: 4.35e+00, Epoch Time: 125.19s
# Patience counter: 7/50
# Epoch 82, Train Loss: -3.49e-02 (ZCA-NLL: -3.49e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.37e+00, Epoch Time: 125.17s
# Patience counter: 8/50
# Epoch 83, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.38e+00, Epoch Time: 125.19s
# Patience counter: 9/50
# Epoch 84, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.35e+00, Epoch Time: 125.17s
# Patience counter: 10/50
# Epoch 85, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.34e+00, Epoch Time: 125.18s
# Patience counter: 11/50
# Epoch 86, Train Loss: -3.49e-02 (ZCA-NLL: -3.49e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.72e-05), Val Loss: 4.39e+00, Epoch Time: 125.22s
# Patience counter: 12/50
# Epoch 87, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.38e+00, Epoch Time: 125.20s
# Patience counter: 13/50
# Epoch 88, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.35e+00, Epoch Time: 125.22s
# Patience counter: 14/50
# Epoch 89, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.32e+00, Epoch Time: 125.21s
# Best model so far saved at epoch 89 (Val Loss: 4.322e+00)
# Epoch 90, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.35e+00, Epoch Time: 125.16s
# Patience counter: 1/50
# Epoch 91, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.69e-05), Val Loss: 4.39e+00, Epoch Time: 125.14s
# Patience counter: 2/50
# Epoch 92, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.38e+00, Epoch Time: 125.14s
# Patience counter: 3/50
# Epoch 93, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.37e+00, Epoch Time: 125.15s
# Patience counter: 4/50
# Epoch 94, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.38e+00, Epoch Time: 125.16s
# Patience counter: 5/50
# Epoch 95, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.35e+00, Epoch Time: 125.19s
# Patience counter: 6/50
# Epoch 96, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.86e-05, Grad-Phys: 7.69e-05), Val Loss: 4.37e+00, Epoch Time: 125.19s
# Patience counter: 7/50
# Epoch 97, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.72e-05), Val Loss: 4.38e+00, Epoch Time: 125.23s
# Patience counter: 8/50
# Epoch 98, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.38e+00, Epoch Time: 125.19s
# Patience counter: 9/50
# Epoch 99, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.37e+00, Epoch Time: 125.17s
# Patience counter: 10/50
# Epoch 100, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.37e+00, Epoch Time: 125.22s
# Patience counter: 11/50
# Epoch 101, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.36e+00, Epoch Time: 125.20s
# Patience counter: 12/50
# Epoch 102, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.38e+00, Epoch Time: 125.24s
# Patience counter: 13/50
# Epoch 103, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.90e-05, Grad-Phys: 7.71e-05), Val Loss: 4.35e+00, Epoch Time: 125.06s
# Patience counter: 14/50
# Epoch 104, Train Loss: -3.48e-02 (ZCA-NLL: -3.48e-02, MSE-Phys: 3.90e-05, Grad-Phys: 7.72e-05), Val Loss: 4.38e+00, Epoch Time: 125.08s
# Patience counter: 15/50
# Epoch 105, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.38e+00, Epoch Time: 125.17s
# Patience counter: 16/50
# Epoch 106, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.70e-05), Val Loss: 4.35e+00, Epoch Time: 125.20s
# Patience counter: 17/50
# Epoch 107, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.70e-05), Val Loss: 4.39e+00, Epoch Time: 124.98s
# Patience counter: 18/50
# Epoch 108, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.36e+00, Epoch Time: 125.11s
# Patience counter: 19/50
# Epoch 109, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.69e-05), Val Loss: 4.39e+00, Epoch Time: 125.19s
# Patience counter: 20/50
# Epoch 110, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.40e+00, Epoch Time: 125.06s
# Patience counter: 21/50
# Epoch 111, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.39e+00, Epoch Time: 125.23s
# Patience counter: 22/50
# Epoch 112, Train Loss: -3.50e-02 (ZCA-NLL: -3.50e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.38e+00, Epoch Time: 125.02s
# Patience counter: 23/50
# Epoch 113, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.39e+00, Epoch Time: 125.25s
# Patience counter: 24/50
# Epoch 114, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.72e-05), Val Loss: 4.36e+00, Epoch Time: 125.10s
# Patience counter: 25/50
# Epoch 115, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.37e+00, Epoch Time: 125.18s
# Patience counter: 26/50
# Epoch 116, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.70e-05), Val Loss: 4.38e+00, Epoch Time: 125.01s
# Patience counter: 27/50
# Epoch 117, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.33e+00, Epoch Time: 125.29s
# Patience counter: 28/50
# Epoch 118, Train Loss: -3.53e-02 (ZCA-NLL: -3.53e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.35e+00, Epoch Time: 125.05s
# Patience counter: 29/50
# Epoch 119, Train Loss: -3.53e-02 (ZCA-NLL: -3.53e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.39e+00, Epoch Time: 125.40s
# Patience counter: 30/50
# Epoch 120, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.37e+00, Epoch Time: 125.05s
# Patience counter: 31/50
# Epoch 121, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.37e+00, Epoch Time: 124.94s
# Patience counter: 32/50
# Epoch 122, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.70e-05), Val Loss: 4.36e+00, Epoch Time: 125.28s
# Patience counter: 33/50
# Epoch 123, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.36e+00, Epoch Time: 125.29s
# Patience counter: 34/50
# Epoch 124, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.70e-05), Val Loss: 4.39e+00, Epoch Time: 125.00s
# Patience counter: 35/50
# Epoch 125, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.35e+00, Epoch Time: 125.06s
# Patience counter: 36/50
# Epoch 126, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.38e+00, Epoch Time: 125.43s
# Patience counter: 37/50
# Epoch 127, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.38e+00, Epoch Time: 125.11s
# Patience counter: 38/50
# Epoch 128, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.38e+00, Epoch Time: 125.04s
# Patience counter: 39/50
# Epoch 129, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.35e+00, Epoch Time: 125.20s
# Patience counter: 40/50
# Epoch 130, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.37e+00, Epoch Time: 125.21s
# Patience counter: 41/50
# Epoch 131, Train Loss: -3.53e-02 (ZCA-NLL: -3.53e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.69e-05), Val Loss: 4.39e+00, Epoch Time: 125.06s
# Patience counter: 42/50
# Epoch 132, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.39e+00, Epoch Time: 124.94s
# Patience counter: 43/50
# Epoch 133, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.38e+00, Epoch Time: 125.04s
# Patience counter: 44/50
# Epoch 134, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.36e+00, Epoch Time: 125.32s
# Patience counter: 45/50
# Epoch 135, Train Loss: -3.53e-02 (ZCA-NLL: -3.53e-02, MSE-Phys: 3.87e-05, Grad-Phys: 7.69e-05), Val Loss: 4.37e+00, Epoch Time: 125.24s
# Patience counter: 46/50
# Epoch 136, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.33e+00, Epoch Time: 124.99s
# Patience counter: 47/50
# Epoch 137, Train Loss: -3.51e-02 (ZCA-NLL: -3.51e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.71e-05), Val Loss: 4.34e+00, Epoch Time: 124.98s
# Patience counter: 48/50
# Epoch 138, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.89e-05, Grad-Phys: 7.71e-05), Val Loss: 4.37e+00, Epoch Time: 125.26s
# Patience counter: 49/50
# Epoch 139, Train Loss: -3.52e-02 (ZCA-NLL: -3.52e-02, MSE-Phys: 3.88e-05, Grad-Phys: 7.70e-05), Val Loss: 4.37e+00, Epoch Time: 125.33s
# Patience counter: 50/50
# Early stopping triggered.
# Training complete
