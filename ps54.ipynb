# %% [markdown]
# # Set up

# %%
import random
import numpy as np
import xarray as xr
import torch
from torch.utils.data import DataLoader, TensorDataset
from unet import *
from train import *
from loss import *

base_path = "gs://leap-persistent/YueWang/SSH/data"

def open_zarr(path):
    return xr.open_zarr(path, consolidated=True)

train = open_zarr(f"{base_path}/train_54_sst.zarr").compute()
val = open_zarr(f"{base_path}/val_54_sst.zarr").compute()
zca = open_zarr(f"{base_path}/zca_54_sst.zarr").compute()

# %%
def min_max_normalize(tensor, min_values=None, max_values=None, feature_range=(0, 1)):

    num_channels = tensor.shape[1]
    
    if min_values is None:
        min_values = torch.zeros(num_channels, device=tensor.device)
        for c in range(num_channels):
            min_values[c] = tensor[:, c, :, :].min()
    
    if max_values is None:
        max_values = torch.zeros(num_channels, device=tensor.device)
        for c in range(num_channels):
            max_values[c] = tensor[:, c, :, :].max()
    
    normalized_tensor = torch.zeros_like(tensor)
    scale = (feature_range[1] - feature_range[0])
    
    # Normalize each channel independently
    for c in range(num_channels):
        channel_range = max_values[c] - min_values[c]
        
        # Handle edge case where min and max are the same
        if channel_range == 0:
            normalized_tensor[:, c, :, :] = feature_range[0]
        else:
            # Apply min-max formula: (x - min) / (max - min) * scale + min_range
            normalized_tensor[:, c, :, :] = (
                (tensor[:, c, :, :] - min_values[c]) / channel_range
            ) * scale + feature_range[0]
    
    return normalized_tensor, min_values, max_values

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Prepare training data
x_train_channel_0 = torch.from_numpy(train.ssh.values).float().unsqueeze(1).to(device)
x_train_channel_1 = torch.from_numpy(train.sst.values).float().unsqueeze(1).to(device)
x_train = torch.cat([x_train_channel_0, x_train_channel_1], dim=1)
x_train_normalized, min_values, max_values = min_max_normalize(x_train)

y_train_channel_0 = torch.from_numpy(train.ubm.values).float().unsqueeze(1).to(device)
y_train_channel_1 = torch.from_numpy(train.zca_ubm.values).float().unsqueeze(1).to(device)
y_train = torch.cat([y_train_channel_0, y_train_channel_1], dim=1)


# Prepare validation data 
x_val_channel_0 = torch.from_numpy(val.ssh.values).float().unsqueeze(1).to(device)
x_val_channel_1 = torch.from_numpy(val.sst.values).float().unsqueeze(1).to(device)
x_val = torch.cat([x_val_channel_0, x_val_channel_1], dim=1)
x_val_normalized, _, _ = min_max_normalize(x_val, min_values=min_values, max_values=max_values)

y_val_channel_0 = torch.from_numpy(val.ubm.values).float().unsqueeze(1).to(device)
y_val_channel_1 = torch.from_numpy(val.zca_ubm.values).float().unsqueeze(1).to(device)  
y_val = torch.cat([y_val_channel_0, y_val_channel_1], dim=1)  

# Create datasets
train_dataset = TensorDataset(x_train_normalized, y_train)
val_dataset = TensorDataset(x_val_normalized, y_val)


# Create data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

Vt = torch.from_numpy(zca.zca_Vt_ubm.values).float().to(device)
scale = torch.from_numpy(zca.zca_scale_ubm.values).float().to(device)
mean = torch.from_numpy(zca.zca_mean_ubm.values).float().to(device)

# %% [markdown]
# # Training

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    

# Create model and optimizer
model = UNet(in_channels=2, out_channels=2, initial_features=32, depth=4)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)


train_model(model, train_loader, val_loader,
            Vt, scale, mean,  
            optimizer, device,
            grad_loss_weight=0.0,      # Weight for gradient loss in physical space
            mse_loss_weight=0.0,       # Weight for MSE loss in physical space  
            zca_nll_weight=1.0,        # Weight for ZCA Gaussian NLL loss
            save_path='/home/jovyan/GRL_ssh/checkpoints/ps54.pth',
            n_epochs=2000,
            patience=50)
# Out:
# Epoch 1, Train Loss: 2.99e-01 (ZCA-NLL: 2.99e-01, MSE-Phys: 1.18e-04, Grad-Phys: 2.64e-04), Val Loss: 1.46e+00, Epoch Time: 154.83s
# Best model so far saved at epoch 1 (Val Loss: 1.455e+00)
# Epoch 2, Train Loss: -2.43e-01 (ZCA-NLL: -2.43e-01, MSE-Phys: 1.28e-04, Grad-Phys: 2.10e-04), Val Loss: 1.11e+00, Epoch Time: 154.68s
# Best model so far saved at epoch 2 (Val Loss: 1.106e+00)
# Epoch 3, Train Loss: -4.11e-01 (ZCA-NLL: -4.11e-01, MSE-Phys: 9.68e-05, Grad-Phys: 1.75e-04), Val Loss: 1.07e+00, Epoch Time: 154.73s
# Best model so far saved at epoch 3 (Val Loss: 1.071e+00)
# Epoch 4, Train Loss: -4.55e-01 (ZCA-NLL: -4.55e-01, MSE-Phys: 8.98e-05, Grad-Phys: 1.65e-04), Val Loss: 1.03e+00, Epoch Time: 154.78s
# Best model so far saved at epoch 4 (Val Loss: 1.034e+00)
# Epoch 5, Train Loss: -4.87e-01 (ZCA-NLL: -4.87e-01, MSE-Phys: 7.81e-05, Grad-Phys: 1.53e-04), Val Loss: 1.01e+00, Epoch Time: 154.80s
# Best model so far saved at epoch 5 (Val Loss: 1.008e+00)
# Epoch 6, Train Loss: -5.05e-01 (ZCA-NLL: -5.05e-01, MSE-Phys: 7.59e-05, Grad-Phys: 1.47e-04), Val Loss: 1.00e+00, Epoch Time: 154.88s
# Best model so far saved at epoch 6 (Val Loss: 1.004e+00)
# Epoch 7, Train Loss: -5.22e-01 (ZCA-NLL: -5.22e-01, MSE-Phys: 7.29e-05, Grad-Phys: 1.42e-04), Val Loss: 1.02e+00, Epoch Time: 154.86s
# Patience counter: 1/50
# Epoch 8, Train Loss: -5.36e-01 (ZCA-NLL: -5.36e-01, MSE-Phys: 7.05e-05, Grad-Phys: 1.38e-04), Val Loss: 9.67e-01, Epoch Time: 154.80s
# Best model so far saved at epoch 8 (Val Loss: 9.667e-01)
# Epoch 9, Train Loss: -5.48e-01 (ZCA-NLL: -5.48e-01, MSE-Phys: 6.83e-05, Grad-Phys: 1.34e-04), Val Loss: 9.87e-01, Epoch Time: 154.71s
# Patience counter: 1/50
# Epoch 10, Train Loss: -5.58e-01 (ZCA-NLL: -5.58e-01, MSE-Phys: 6.56e-05, Grad-Phys: 1.30e-04), Val Loss: 9.68e-01, Epoch Time: 154.63s
# Patience counter: 2/50
# Epoch 11, Train Loss: -5.66e-01 (ZCA-NLL: -5.66e-01, MSE-Phys: 6.32e-05, Grad-Phys: 1.26e-04), Val Loss: 9.47e-01, Epoch Time: 155.22s
# Best model so far saved at epoch 11 (Val Loss: 9.474e-01)
# Epoch 12, Train Loss: -5.72e-01 (ZCA-NLL: -5.72e-01, MSE-Phys: 6.19e-05, Grad-Phys: 1.24e-04), Val Loss: 9.64e-01, Epoch Time: 155.08s
Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.46e-05, Grad-Phys: 8.36e-05), Val Loss: 9.05e-01, Epoch Time: 154.83s
# Patience counter: 8/50
# Epoch 68, Train Loss: -6.66e-01 (ZCA-NLL: -6.66e-01, MSE-Phys: 3.46e-05, Grad-Phys: 8.35e-05), Val Loss: 9.02e-01, Epoch Time: 154.53s
# Patience counter: 9/50
# Epoch 69, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.45e-05, Grad-Phys: 8.35e-05), Val Loss: 9.02e-01, Epoch Time: 154.74s
# Patience counter: 10/50
# Epoch 70, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.45e-05, Grad-Phys: 8.33e-05), Val Loss: 9.05e-01, Epoch Time: 154.84s
# Patience counter: 11/50
# Epoch 71, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.45e-05, Grad-Phys: 8.34e-05), Val Loss: 9.02e-01, Epoch Time: 154.73s
# Patience counter: 12/50
# Epoch 72, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.44e-05, Grad-Phys: 8.33e-05), Val Loss: 9.05e-01, Epoch Time: 154.63s
# Patience counter: 13/50
# Epoch 73, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.43e-05, Grad-Phys: 8.31e-05), Val Loss: 9.02e-01, Epoch Time: 154.92s
# Patience counter: 14/50
# Epoch 74, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.43e-05, Grad-Phys: 8.31e-05), Val Loss: 9.03e-01, Epoch Time: 154.48s
# Patience counter: 15/50
# Epoch 75, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.43e-05, Grad-Phys: 8.31e-05), Val Loss: 9.02e-01, Epoch Time: 154.58s
# Patience counter: 16/50
# Epoch 76, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.42e-05, Grad-Phys: 8.31e-05), Val Loss: 9.02e-01, Epoch Time: 154.67s
# Patience counter: 17/50
# Epoch 77, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.43e-05, Grad-Phys: 8.30e-05), Val Loss: 9.01e-01, Epoch Time: 154.62s
# Patience counter: 18/50
# Epoch 78, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.42e-05, Grad-Phys: 8.30e-05), Val Loss: 9.02e-01, Epoch Time: 154.81s
# Patience counter: 19/50
# Epoch 79, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.42e-05, Grad-Phys: 8.30e-05), Val Loss: 9.06e-01, Epoch Time: 155.22s
# Patience counter: 20/50
# Epoch 80, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.29e-05), Val Loss: 9.04e-01, Epoch Time: 155.05s
# Patience counter: 21/50
# Epoch 81, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.29e-05), Val Loss: 9.03e-01, Epoch Time: 155.11s
# Patience counter: 22/50
# Epoch 82, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.29e-05), Val Loss: 9.01e-01, Epoch Time: 154.84s
# Best model so far saved at epoch 82 (Val Loss: 9.006e-01)
# Epoch 83, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.42e-05, Grad-Phys: 8.29e-05), Val Loss: 9.02e-01, Epoch Time: 154.93s
# Patience counter: 1/50
# Epoch 84, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.29e-05), Val Loss: 9.01e-01, Epoch Time: 154.89s
# Patience counter: 2/50
# Epoch 85, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.29e-05), Val Loss: 9.03e-01, Epoch Time: 155.09s
# Patience counter: 3/50
# Epoch 86, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.29e-05), Val Loss: 9.03e-01, Epoch Time: 155.06s
# Patience counter: 4/50
# Epoch 87, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.42e-05, Grad-Phys: 8.30e-05), Val Loss: 9.03e-01, Epoch Time: 154.91s
# Patience counter: 5/50
# Epoch 88, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.01e-01, Epoch Time: 154.91s
# Best model so far saved at epoch 88 (Val Loss: 9.005e-01)
# Epoch 89, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.28e-05), Val Loss: 9.02e-01, Epoch Time: 154.91s
# Patience counter: 1/50
# Epoch 90, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.04e-01, Epoch Time: 154.91s
# Patience counter: 2/50
# Epoch 91, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 155.29s
# Patience counter: 3/50
# Epoch 92, Train Loss: -6.67e-01 (ZCA-NLL: -6.67e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.29e-05), Val Loss: 9.03e-01, Epoch Time: 154.97s
# Patience counter: 4/50
# Epoch 93, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.02e-01, Epoch Time: 154.64s
# Patience counter: 5/50
# Epoch 94, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.01e-01, Epoch Time: 154.70s
# Patience counter: 6/50
# Epoch 95, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.02e-01, Epoch Time: 154.66s
# Patience counter: 7/50
# Epoch 96, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.00e-01, Epoch Time: 154.83s
# Best model so far saved at epoch 96 (Val Loss: 8.996e-01)
# Epoch 97, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.28e-05), Val Loss: 9.05e-01, Epoch Time: 155.23s
# Patience counter: 1/50
# Epoch 98, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 154.64s
# Patience counter: 2/50
# Epoch 99, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.28e-05), Val Loss: 9.03e-01, Epoch Time: 154.58s
# Patience counter: 3/50
# Epoch 100, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 155.50s
# Patience counter: 4/50
# Epoch 101, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.04e-01, Epoch Time: 155.54s
# Patience counter: 5/50
# Epoch 102, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 155.24s
# Patience counter: 6/50
# Epoch 103, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.28e-05), Val Loss: 9.02e-01, Epoch Time: 154.77s
# Patience counter: 7/50
# Epoch 104, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.05e-01, Epoch Time: 154.75s
# Patience counter: 8/50
# Epoch 105, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.06e-01, Epoch Time: 155.60s
# Patience counter: 9/50
# Epoch 106, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.01e-01, Epoch Time: 155.77s
# Patience counter: 10/50
# Epoch 107, Train Loss: -5.77e-01 (ZCA-NLL: -5.77e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.00e-01, Epoch Time: 155.15s
# Patience counter: 11/50
# Epoch 108, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.05e-01, Epoch Time: 155.31s
# Patience counter: 12/50
# Epoch 109, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.28e-05), Val Loss: 9.03e-01, Epoch Time: 155.11s
# Patience counter: 13/50
# Epoch 110, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.05e-01, Epoch Time: 155.25s
# Patience counter: 14/50
# Epoch 111, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.04e-01, Epoch Time: 155.11s
# Patience counter: 15/50
# Epoch 112, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 154.96s
# Patience counter: 16/50
# Epoch 113, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 155.12s
# Patience counter: 17/50
# Epoch 114, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.05e-01, Epoch Time: 155.11s
# Patience counter: 18/50
# Epoch 115, Train Loss: -6.69e-01 (ZCA-NLL: -6.69e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 8.99e-01, Epoch Time: 155.70s
# Best model so far saved at epoch 115 (Val Loss: 8.993e-01)
# Epoch 116, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.02e-01, Epoch Time: 155.62s
# Patience counter: 1/50
# Epoch 117, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.02e-01, Epoch Time: 155.71s
# Patience counter: 2/50
# Epoch 118, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.02e-01, Epoch Time: 155.29s
# Patience counter: 3/50
# Epoch 119, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 155.02s
# Patience counter: 4/50
# Epoch 120, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 154.89s
# Patience counter: 5/50
# Epoch 121, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.01e-01, Epoch Time: 154.90s
# Patience counter: 6/50
# Epoch 122, Train Loss: -6.69e-01 (ZCA-NLL: -6.69e-01, MSE-Phys: 3.38e-05, Grad-Phys: 8.25e-05), Val Loss: 9.05e-01, Epoch Time: 154.84s
# Patience counter: 7/50
# Epoch 123, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 154.87s
# Patience counter: 8/50
# Epoch 124, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.00e-01, Epoch Time: 154.80s
# Patience counter: 9/50
# Epoch 125, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.01e-01, Epoch Time: 154.84s
# Patience counter: 10/50
# Epoch 126, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.04e-01, Epoch Time: 155.46s
# Patience counter: 11/50
# Epoch 127, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.04e-01, Epoch Time: 155.67s
# Patience counter: 12/50
# Epoch 128, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.01e-01, Epoch Time: 155.67s
# Patience counter: 13/50
# Epoch 129, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 155.66s
# Patience counter: 14/50
# Epoch 130, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.01e-01, Epoch Time: 155.75s
# Patience counter: 15/50
# Epoch 131, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 155.59s
# Patience counter: 16/50
# Epoch 132, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 154.79s
# Patience counter: 17/50
# Epoch 133, Train Loss: -6.69e-01 (ZCA-NLL: -6.69e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 154.99s
# Patience counter: 18/50
# Epoch 134, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.04e-01, Epoch Time: 155.38s
# Patience counter: 19/50
# Epoch 135, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 155.69s
# Patience counter: 20/50
# Epoch 136, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.01e-01, Epoch Time: 155.73s
# Patience counter: 21/50
# Epoch 137, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.28e-05), Val Loss: 9.03e-01, Epoch Time: 155.61s
# Patience counter: 22/50
# Epoch 138, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.02e-01, Epoch Time: 155.71s
# Patience counter: 23/50
# Epoch 139, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 155.68s
# Patience counter: 24/50
# Epoch 140, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 154.98s
# Patience counter: 25/50
# Epoch 141, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.02e-01, Epoch Time: 154.94s
# Patience counter: 26/50
# Epoch 142, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 155.00s
# Patience counter: 27/50
# Epoch 143, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.05e-01, Epoch Time: 155.00s
# Patience counter: 28/50
# Epoch 144, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.04e-01, Epoch Time: 154.93s
# Patience counter: 29/50
# Epoch 145, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.01e-01, Epoch Time: 155.03s
# Patience counter: 30/50
# Epoch 146, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 155.04s
# Patience counter: 31/50
# Epoch 147, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 155.02s
# Patience counter: 32/50
# Epoch 148, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.01e-01, Epoch Time: 154.90s
# Patience counter: 33/50
# Epoch 149, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 154.97s
# Patience counter: 34/50
# Epoch 150, Train Loss: -6.69e-01 (ZCA-NLL: -6.69e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.25e-05), Val Loss: 9.03e-01, Epoch Time: 154.93s
# Patience counter: 35/50
# Epoch 151, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.05e-01, Epoch Time: 154.98s
# Patience counter: 36/50
# Epoch 152, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 155.10s
# Patience counter: 37/50
# Epoch 153, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.02e-01, Epoch Time: 155.12s
# Patience counter: 38/50
# Epoch 154, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.01e-01, Epoch Time: 155.11s
# Patience counter: 39/50
# Epoch 155, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.03e-01, Epoch Time: 155.11s
# Patience counter: 40/50
# Epoch 156, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.04e-01, Epoch Time: 155.11s
# Patience counter: 41/50
# Epoch 157, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 154.97s
# Patience counter: 42/50
# Epoch 158, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.01e-01, Epoch Time: 155.09s
# Patience counter: 43/50
# Epoch 159, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 154.96s
# Patience counter: 44/50
# Epoch 160, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.41e-05, Grad-Phys: 8.28e-05), Val Loss: 9.03e-01, Epoch Time: 155.24s
# Patience counter: 45/50
# Epoch 161, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.05e-01, Epoch Time: 155.46s
# Patience counter: 46/50
# Epoch 162, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.40e-05, Grad-Phys: 8.27e-05), Val Loss: 9.02e-01, Epoch Time: 155.36s
# Patience counter: 47/50
# Epoch 163, Train Loss: -6.69e-01 (ZCA-NLL: -6.69e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 155.11s
# Patience counter: 48/50
# Epoch 164, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.03e-01, Epoch Time: 155.00s
# Patience counter: 49/50
# Epoch 165, Train Loss: -6.68e-01 (ZCA-NLL: -6.68e-01, MSE-Phys: 3.39e-05, Grad-Phys: 8.26e-05), Val Loss: 9.02e-01, Epoch Time: 155.02s
# Patience counter: 50/50
# Early stopping triggered.
# Training complete
