# %% [markdown]
# # Set up

# %%
import random
import numpy as np
import xarray as xr
import torch
from torch.utils.data import DataLoader, TensorDataset
from unet import *
from train import *
from loss import *

base_path = "gs://leap-persistent/YueWang/SSH/data"

def open_zarr(path):
    return xr.open_zarr(path, consolidated=True)

train = open_zarr(f"{base_path}/train_80_sst.zarr").compute()
val = open_zarr(f"{base_path}/val_80_sst.zarr").compute()
zca = open_zarr(f"{base_path}/zca_80_sst.zarr").compute()

# %%
def min_max_normalize(tensor, min_values=None, max_values=None, feature_range=(0, 1)):

    num_channels = tensor.shape[1]
    
    if min_values is None:
        min_values = torch.zeros(num_channels, device=tensor.device)
        for c in range(num_channels):
            min_values[c] = tensor[:, c, :, :].min()
    
    if max_values is None:
        max_values = torch.zeros(num_channels, device=tensor.device)
        for c in range(num_channels):
            max_values[c] = tensor[:, c, :, :].max()
    
    normalized_tensor = torch.zeros_like(tensor)
    scale = (feature_range[1] - feature_range[0])
    
    # Normalize each channel independently
    for c in range(num_channels):
        channel_range = max_values[c] - min_values[c]
        
        # Handle edge case where min and max are the same
        if channel_range == 0:
            normalized_tensor[:, c, :, :] = feature_range[0]
        else:
            # Apply min-max formula: (x - min) / (max - min) * scale + min_range
            normalized_tensor[:, c, :, :] = (
                (tensor[:, c, :, :] - min_values[c]) / channel_range
            ) * scale + feature_range[0]
    
    return normalized_tensor, min_values, max_values

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Prepare training data - SSH only
x_train = torch.from_numpy(train.ssh.values).float().unsqueeze(1).to(device)  # Single channel SSH
x_train_normalized, min_values, max_values = min_max_normalize(x_train)

y_train_channel_0 = torch.from_numpy(train.ubm.values).float().unsqueeze(1).to(device)
y_train_channel_1 = torch.from_numpy(train.zca_ubm.values).float().unsqueeze(1).to(device)
y_train = torch.cat([y_train_channel_0, y_train_channel_1], dim=1)

# Prepare validation data - SSH only
x_val = torch.from_numpy(val.ssh.values).float().unsqueeze(1).to(device)  # Single channel SSH
x_val_normalized, _, _ = min_max_normalize(x_val, min_values=min_values, max_values=max_values)

y_val_channel_0 = torch.from_numpy(val.ubm.values).float().unsqueeze(1).to(device)
y_val_channel_1 = torch.from_numpy(val.zca_ubm.values).float().unsqueeze(1).to(device)
y_val = torch.cat([y_val_channel_0, y_val_channel_1], dim=1)

# Create datasets
train_dataset = TensorDataset(x_train_normalized, y_train)
val_dataset = TensorDataset(x_val_normalized, y_val)

# Create data loaders
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# ZCA parameters 
Vt = torch.from_numpy(zca.zca_Vt_ubm.values).float().to(device)
scale = torch.from_numpy(zca.zca_scale_ubm.values).float().to(device)
mean = torch.from_numpy(zca.zca_mean_ubm.values).float().to(device)

# %% [markdown]
# # Training

# %%
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed(42)
    torch.cuda.manual_seed_all(42)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    

# Create model and optimizer
model = UNet(in_channels=1, out_channels=2, initial_features=32, depth=4)
model.to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)


train_model(model, train_loader, val_loader,
            Vt, scale, mean,  
            optimizer, device,
            grad_loss_weight=0.0,      # Weight for gradient loss in physical space
            mse_loss_weight=0.0,       # Weight for MSE loss in physical space  
            zca_nll_weight=1.0,        # Weight for ZCA Gaussian NLL loss
            save_path='/home/jovyan/GRL_ssh/checkpoints/ssh_input_only.pth',
            n_epochs=2000,
            patience=50)
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# Epoch 
# Epoch 12, Train Loss: -2.70e-01 (ZCA-NLL: -2.70e-01, MSE-Phys: 6.78e-05, Grad-Phys: 1.23e-04), Val Loss: 1.57e+00, Epoch Time: 121.89s
# Patience counter: 2/50
# Epoch 13, Train Loss: -2.76e-01 (ZCA-NLL: -2.76e-01, MSE-Phys: 6.62e-05, Grad-Phys: 1.20e-04), Val Loss: 1.59e+00, Epoch Time: 121.90s
# Patience counter: 3/50
# Epoch 14, Train Loss: -2.80e-01 (ZCA-NLL: -2.80e-01, MSE-Phys: 6.48e-05, Grad-Phys: 1.19e-04), Val Loss: 1.60e+00, Epoch Time: 121.94s
# Patience counter: 4/50
# Epoch 15, Train Loss: -2.83e-01 (ZCA-NLL: -2.83e-01, MSE-Phys: 6.40e-05, Grad-Phys: 1.17e-04), Val Loss: 1.66e+00, Epoch Time: 121.87s
# Patience counter: 5/50
# Epoch 16, Train Loss: -2.87e-01 (ZCA-NLL: -2.87e-01, MSE-Phys: 6.26e-05, Grad-Phys: 1.16e-04), Val Loss: 1.51e+00, Epoch Time: 121.92s
# Best model so far saved at epoch 16 (Val Loss: 1.514e+00)
# Epoch 17, Train Loss: -2.90e-01 (ZCA-NLL: -2.90e-01, MSE-Phys: 6.17e-05, Grad-Phys: 1.15e-04), Val Loss: 1.58e+00, Epoch Time: 122.06s
# Patience counter: 1/50
# Epoch 18, Train Loss: -2.93e-01 (ZCA-NLL: -2.93e-01, MSE-Phys: 6.08e-05, Grad-Phys: 1.13e-04), Val Loss: 1.56e+00, Epoch Time: 121.99s
# Patience counter: 2/50
# Epoch 19, Train Loss: -2.95e-01 (ZCA-NLL: -2.95e-01, MSE-Phys: 5.96e-05, Grad-Phys: 1.12e-04), Val Loss: 1.54e+00, Epoch Time: 121.96s
# Patience counter: 3/50
# Epoch 20, Train Loss: -2.98e-01 (ZCA-NLL: -2.98e-01, MSE-Phys: 5.85e-05, Grad-Phys: 1.11e-04), Val Loss: 1.59e+00, Epoch Time: 121.79s
# Patience counter: 4/50
# Epoch 21, Train Loss: -3.01e-01 (ZCA-NLL: -3.01e-01, MSE-Phys: 5.72e-05, Grad-Phys: 1.09e-04), Val Loss: 1.55e+00, Epoch Time: 121.88s
# Patience counter: 5/50
# Epoch 22, Train Loss: -3.02e-01 (ZCA-NLL: -3.02e-01, MSE-Phys: 5.64e-05, Grad-Phys: 1.08e-04), Val Loss: 1.53e+00, Epoch Time: 121.87s
# Patience counter: 6/50
# Epoch 23, Train Loss: -3.11e-01 (ZCA-NLL: -3.11e-01, MSE-Phys: 5.29e-05, Grad-Phys: 1.04e-04), Val Loss: 1.53e+00, Epoch Time: 121.99s
# Patience counter: 7/50
# Epoch 24, Train Loss: -3.13e-01 (ZCA-NLL: -3.13e-01, MSE-Phys: 5.21e-05, Grad-Phys: 1.03e-04), Val Loss: 1.54e+00, Epoch Time: 122.00s
# Patience counter: 8/50
# Epoch 51, Train Loss: -3.37e-01 (ZCA-NLL: -3.37e-01, MSE-Phys: 3.87e-05, Grad-Phys: 8.65e-05), Val Loss: 1.50e+00, Epoch Time: 121.99s
# Patience counter: 1/50
# Epoch 52, Train Loss: -3.37e-01 (ZCA-NLL: -3.37e-01, MSE-Phys: 3.86e-05, Grad-Phys: 8.63e-05), Val Loss: 1.50e+00, Epoch Time: 121.94s
# Best model so far saved at epoch 52 (Val Loss: 1.498e+00)
# Epoch 53, Train Loss: -3.38e-01 (ZCA-NLL: -3.38e-01, MSE-Phys: 3.85e-05, Grad-Phys: 8.62e-05), Val Loss: 1.51e+00, Epoch Time: 121.97s
# Patience counter: 1/50
# Epoch 54, Train Loss: -3.38e-01 (ZCA-NLL: -3.38e-01, MSE-Phys: 3.83e-05, Grad-Phys: 8.59e-05), Val Loss: 1.50e+00, Epoch Time: 121.88s
# Patience counter: 2/50
# Epoch 55, Train Loss: -3.38e-01 (ZCA-NLL: -3.38e-01, MSE-Phys: 3.82e-05, Grad-Phys: 8.59e-05), Val Loss: 1.50e+00, Epoch Time: 121.78s
# Patience counter: 3/50
# Epoch 56, Train Loss: -3.38e-01 (ZCA-NLL: -3.38e-01, MSE-Phys: 3.82e-05, Grad-Phys: 8.58e-05), Val Loss: 1.51e+00, Epoch Time: 122.17s
# Patience counter: 4/50
# Epoch 57, Train Loss: -3.38e-01 (ZCA-NLL: -3.38e-01, MSE-Phys: 3.80e-05, Grad-Phys: 8.56e-05), Val Loss: 1.51e+00, Epoch Time: 121.78s
# Patience counter: 5/50
# Epoch 58, Train Loss: -3.38e-01 (ZCA-NLL: -3.38e-01, MSE-Phys: 3.79e-05, Grad-Phys: 8.55e-05), Val Loss: 1.51e+00, Epoch Time: 121.80s
# Patience counter: 6/50
# Epoch 59, Train Loss: -3.39e-01 (ZCA-NLL: -3.39e-01, MSE-Phys: 3.75e-05, Grad-Phys: 8.51e-05), Val Loss: 1.51e+00, Epoch Time: 121.92s
# Patience counter: 7/50
# Epoch 60, Train Loss: -3.39e-01 (ZCA-NLL: -3.39e-01, MSE-Phys: 3.76e-05, Grad-Phys: 8.51e-05), Val Loss: 1.51e+00, Epoch Time: 122.00s
# Patience counter: 8/50
# Epoch 61, Train Loss: -3.39e-01 (ZCA-NLL: -3.39e-01, MSE-Phys: 3.75e-05, Grad-Phys: 8.50e-05), Val Loss: 1.51e+00, Epoch Time: 121.79s
# Patience counter: 9/50
# Epoch 62, Train Loss: -3.39e-01 (ZCA-NLL: -3.39e-01, MSE-Phys: 3.78e-05, Grad-Phys: 8.52e-05), Val Loss: 1.50e+00, Epoch Time: 121.79s
# Patience counter: 10/50
# Epoch 63, Train Loss: -3.39e-01 (ZCA-NLL: -3.39e-01, MSE-Phys: 3.75e-05, Grad-Phys: 8.49e-05), Val Loss: 1.50e+00, Epoch Time: 121.65s
# Patience counter: 11/50
# Epoch 64, Train Loss: -3.39e-01 (ZCA-NLL: -3.39e-01, MSE-Phys: 3.73e-05, Grad-Phys: 8.48e-05), Val Loss: 1.50e+00, Epoch Time: 121.75s
# Patience counter: 12/50
# Epoch 65, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.72e-05, Grad-Phys: 8.47e-05), Val Loss: 1.50e+00, Epoch Time: 121.63s
# Patience counter: 13/50
# Epoch 66, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.74e-05, Grad-Phys: 8.48e-05), Val Loss: 1.51e+00, Epoch Time: 121.58s
# Patience counter: 14/50
# Epoch 67, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.72e-05, Grad-Phys: 8.46e-05), Val Loss: 1.50e+00, Epoch Time: 121.65s
# Patience counter: 15/50
# Epoch 68, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.73e-05, Grad-Phys: 8.47e-05), Val Loss: 1.50e+00, Epoch Time: 121.95s
# Patience counter: 16/50
# Epoch 69, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.73e-05, Grad-Phys: 8.47e-05), Val Loss: 1.50e+00, Epoch Time: 121.76s
# Patience counter: 17/50
# Epoch 70, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.73e-05, Grad-Phys: 8.46e-05), Val Loss: 1.51e+00, Epoch Time: 122.00s
# Patience counter: 18/50
# Epoch 71, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.71e-05, Grad-Phys: 8.44e-05), Val Loss: 1.50e+00, Epoch Time: 121.82s
# Patience counter: 19/50
# Epoch 72, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.71e-05, Grad-Phys: 8.44e-05), Val Loss: 1.50e+00, Epoch Time: 121.76s
# Patience counter: 20/50
# Epoch 73, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.71e-05, Grad-Phys: 8.44e-05), Val Loss: 1.50e+00, Epoch Time: 121.83s
# Patience counter: 21/50
# Epoch 74, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.70e-05, Grad-Phys: 8.43e-05), Val Loss: 1.50e+00, Epoch Time: 121.94s
# Patience counter: 22/50
# Epoch 76, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.71e-05, Grad-Phys: 8.44e-05), Val Loss: 1.50e+00, Epoch Time: 122.11s
# Patience counter: 24/50
# Epoch 77, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 122.16s
# Patience counter: 25/50
# Epoch 78, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 121.93s
# Patience counter: 26/50
# Epoch 79, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.70e-05, Grad-Phys: 8.43e-05), Val Loss: 1.50e+00, Epoch Time: 122.02s
# Patience counter: 27/50
# Epoch 80, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.70e-05, Grad-Phys: 8.43e-05), Val Loss: 1.50e+00, Epoch Time: 121.91s
# Patience counter: 28/50
# Epoch 81, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.70e-05, Grad-Phys: 8.43e-05), Val Loss: 1.50e+00, Epoch Time: 121.85s
# Patience counter: 29/50
# Epoch 82, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.51e+00, Epoch Time: 121.96s
# Patience counter: 30/50
# Epoch 83, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.51e+00, Epoch Time: 121.88s
# Patience counter: 31/50
# Epoch 84, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.51e+00, Epoch Time: 121.91s
# Patience counter: 32/50
# Epoch 85, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.43e-05), Val Loss: 1.50e+00, Epoch Time: 121.84s
# Patience counter: 33/50
# Epoch 86, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.70e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 121.80s
# Patience counter: 34/50
# Epoch 87, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 122.00s
# Patience counter: 35/50
# Epoch 88, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 122.18s
# Patience counter: 36/50
# Epoch 89, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.51e+00, Epoch Time: 121.99s
# Patience counter: 37/50
# Epoch 90, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 122.02s
# Patience counter: 38/50
# Epoch 91, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.70e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 122.01s
# Patience counter: 39/50
# Epoch 92, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 121.81s
# Patience counter: 40/50
# Epoch 93, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 121.75s
# Patience counter: 41/50
# Epoch 94, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 122.14s
# Patience counter: 42/50
# Epoch 95, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 121.95s
# Patience counter: 43/50
# Epoch 96, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 121.81s
# Patience counter: 44/50
# Epoch 97, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 121.67s
# Patience counter: 45/50
# Epoch 98, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 121.74s
# Patience counter: 46/50
# Epoch 99, Train Loss: -3.40e-01 (ZCA-NLL: -3.40e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 121.77s
# Patience counter: 47/50
# Epoch 100, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 121.99s
# Patience counter: 48/50
# Epoch 101, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.69e-05, Grad-Phys: 8.42e-05), Val Loss: 1.50e+00, Epoch Time: 121.91s
# Patience counter: 49/50
# Epoch 102, Train Loss: -3.41e-01 (ZCA-NLL: -3.41e-01, MSE-Phys: 3.68e-05, Grad-Phys: 8.41e-05), Val Loss: 1.50e+00, Epoch Time: 121.69s
# Patience counter: 50/50
# Early stopping triggered.
# Training complete
